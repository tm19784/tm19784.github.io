# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import requests
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
monthlyInflation=pd.read_csv('inflationCPI_OECD_monthly.csv')
monthlyInflation
usefulMonthlyInflation=monthlyInflation[['LOCATION','TIME','Value']]

# %%
url ='https://raw.githubusercontent.com/tm19784/tm19784.github.io/main/jsonFolder/rawPriceBTC.json'
html = requests.get(url)

# %%
Bitcoin_price_json = html.json()
BTC=pd.DataFrame(Bitcoin_price_json)
BTC_useful=BTC[['time_close','price_close']]
BTC_useful
# Out:
#                        time_close  price_close
# 0    2015-04-29T16:21:00.0000000Z       146.12
# 1    2015-05-09T20:13:18.0000000Z       154.44
# 2    2015-05-19T22:52:30.5100000Z       149.86
# 3    2015-05-29T19:45:01.0000000Z       154.88
# 4    2015-06-08T22:20:07.0000000Z       149.16
# ..                            ...          ...
# 238  2021-11-03T23:59:59.1590000Z     45971.73
# 239  2021-11-13T23:59:53.8400240Z     48097.75
# 240  2021-11-23T23:59:57.5870000Z     43078.60
# 241  2021-12-03T23:59:57.3880000Z     40643.28
# 242  2021-12-06T13:41:17.5611960Z     36532.53
#
# [243 rows x 2 columns]

# %%
BTC_useful['time_close'] = pd.to_datetime(BTC_useful['time_close'])
BTC_useful
BTC_monthly = BTC_useful.set_index('time_close').resample('1M').mean().reset_index()
BTC_monthly
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                   time_close   price_close
# 0  2015-04-30 00:00:00+00:00    146.120000
# 1  2015-05-31 00:00:00+00:00    153.060000
# 2  2015-06-30 00:00:00+00:00    154.970000
# 3  2015-07-31 00:00:00+00:00    181.003333
# 4  2015-08-31 00:00:00+00:00    162.856667
# ..                       ...           ...
# 76 2021-08-31 00:00:00+00:00  32926.090000
# 77 2021-09-30 00:00:00+00:00  33857.720000
# 78 2021-10-31 00:00:00+00:00  40583.986667
# 79 2021-11-30 00:00:00+00:00  45716.026667
# 80 2021-12-31 00:00:00+00:00  38587.905000
#
# [81 rows x 2 columns]

# %%
usefulMonthlyInflation['TIME'] = pd.to_datetime(usefulMonthlyInflation['TIME'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Ger_usefulMonthlyInflation = usefulMonthlyInflation[usefulMonthlyInflation['LOCATION'].str.contains('DEU')]
Ger_usefulMonthlyInflation.reset_index()
# Out:
#     index LOCATION       TIME     Value
# 0       0      DEU 2015-01-01 -0.283286
# 1       1      DEU 2015-02-01 -0.046563
# 2       2      DEU 2015-03-01  0.174787
# 3       3      DEU 2015-04-01  0.866233
# 4       4      DEU 2015-05-01  1.162551
# ..    ...      ...        ...       ...
# 78     78      DEU 2021-07-01  3.770028
# 79     79      DEU 2021-08-01  3.867924
# 80     80      DEU 2021-09-01  4.064272
# 81     81      DEU 2021-10-01  4.532578
# 82     82      DEU 2021-11-01  5.238095
#
# [83 rows x 4 columns]

# %%
Ger_BTC = Ger_usefulMonthlyInflation[-78:].reset_index()[['LOCATION', 'TIME', 'Value']].join(BTC_monthly)
Ger_BTC
# Out:
#    LOCATION       TIME     Value                time_close   price_close
# 0       DEU 2015-06-01  0.878120 2015-04-30 00:00:00+00:00    146.120000
# 1       DEU 2015-07-01  0.795673 2015-05-31 00:00:00+00:00    153.060000
# 2       DEU 2015-08-01  0.795673 2015-06-30 00:00:00+00:00    154.970000
# 3       DEU 2015-09-01  0.595284 2015-07-31 00:00:00+00:00    181.003333
# 4       DEU 2015-10-01  0.878120 2015-08-31 00:00:00+00:00    162.856667
# ..      ...        ...       ...                       ...           ...
# 73      DEU 2021-07-01  3.770028 2021-05-31 00:00:00+00:00  33007.263333
# 74      DEU 2021-08-01  3.867924 2021-06-30 00:00:00+00:00  25347.843333
# 75      DEU 2021-09-01  4.064272 2021-07-31 00:00:00+00:00  24324.596667
# 76      DEU 2021-10-01  4.532578 2021-08-31 00:00:00+00:00  32926.090000
# 77      DEU 2021-11-01  5.238095 2021-09-30 00:00:00+00:00  33857.720000
#
# [78 rows x 5 columns]

# %%
Ger_BTC.rename(columns={'Value': 'Germany_inflation_rate'}, inplace=True)
Ger_BTC.rename(columns={'price_close': 'BTC_closing_price'}, inplace=True)

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import seaborn as sns
sns.set()

# %%
Ger_BTC_correlation = Ger_BTC[['Germany_inflation_rate','BTC_closing_price']]
Ger_BTC.to_csv('Ger_BTC.csv')
Germany_Bitcoin_correlation = pd.read_csv('Ger_BTC.csv')

# %%
sns.regplot(x='BTC_closing_price',y='Germany_inflation_rate',data=Germany_Bitcoin_correlation).set(title='Regression of closing price of Ethereum on inflation rate of Japan')
# Out:
# [Text(0.5, 1.0, 'Regression of closing price of Ethereum on inflation rate of Japan')]

# %%
from scipy.stats import linregress

# %%
slope, intercept, rvalue, pvalue, stderr = linregress(x=Germany_Bitcoin_correlation.dropna()['BTC_closing_price'], y=Germany_Bitcoin_correlation.dropna()['Germany_inflation_rate'])

# %%
regression_equation = print('y = ',np.round(slope,2),' * x + ',np.round(intercept,2))
regression_R2 = print('R² = ',np.round(rvalue**2,2))
# Out:
# y =  0.0  * x +  0.85
# R² =  0.41

# %%
x = Germany_Bitcoin_correlation.dropna()['BTC_closing_price']
y = Germany_Bitcoin_correlation.dropna()['Germany_inflation_rate']

poly_model = make_pipeline(PolynomialFeatures(8),
                           LinearRegression())
poly_model.fit(x[:, np.newaxis], y)
xfit = np.linspace(min(x), max(x), 1000)
yfit = poly_model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit,color='crimson');
plt.xlabel('Ethereum Closing Price')
plt.ylabel('Japanese Inflation Rate')
plt.title('Relationship between Ethereum price and Japanese inflation')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# Text(0.5, 1.0, 'Relationship between Ethereum price and Japanese inflation')

# %%
df_fitz = pd.DataFrame(xfit,yfit)
df_fitz.rename({'index':'yfit'}, inplace=True)
df_fitz_2 = df_fitz.reset_index()
df_fitz_2.rename(columns={'index':'yfit'}, inplace=True)
df_fitz_2.rename(columns={0:'xfit'}, inplace=True)
df_fitz_2
# Out:
#          yfit          xfit
# 0    1.085038    146.120000
# 1    1.085038    187.461738
# 2    1.085038    228.803477
# 3    1.085038    270.145215
# 4    1.085038    311.486954
# ..        ...           ...
# 995  2.385049  41281.149713
# 996  2.385375  41322.491451
# 997  2.386064  41363.833190
# 998  2.387123  41405.174928
# 999  2.388560  41446.516667
#
# [1000 rows x 2 columns]

# %%
Regression_output_table = pd.concat([Germany_Bitcoin_correlation, df_fitz_2])
Regression_output_table.head(85)
# Out:
#     Unnamed: 0 LOCATION        TIME  ...  BTC_closing_price      yfit        xfit
# 0          0.0      DEU  2015-06-01  ...         146.120000       NaN         NaN
# 1          1.0      DEU  2015-07-01  ...         153.060000       NaN         NaN
# 2          2.0      DEU  2015-08-01  ...         154.970000       NaN         NaN
# 3          3.0      DEU  2015-09-01  ...         181.003333       NaN         NaN
# 4          4.0      DEU  2015-10-01  ...         162.856667       NaN         NaN
# ..         ...      ...         ...  ...                ...       ...         ...
# 2          NaN      NaN         NaN  ...                NaN  1.085038  228.803477
# 3          NaN      NaN         NaN  ...                NaN  1.085038  270.145215
# 4          NaN      NaN         NaN  ...                NaN  1.085038  311.486954
# 5          NaN      NaN         NaN  ...                NaN  1.085038  352.828692
# ...

# %%
Regression_output_table.to_csv('inflation_Regression_output_Ger_BTC.csv')
